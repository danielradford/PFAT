# %%
import numpy as np
import pandas as pd 
from statsmodels import regression
import statsmodels.api as sm
import matplotlib.pyplot as plt
import pandas_datareader as web

# %%
start = '2016-01-01'
end = '2017-01-01'

# %%
data = web.DataReader('AAPL','yahoo',start,end)

# %%
asset=data['Adj Close']

# %%
benchmark = web.DataReader('SPY','yahoo',start,end)

# %%
bnchmrk = benchmark['Adj Close']

# %%
asset_ret = asset.pct_change(1)[1:]

# %%
bnchmrk_ret = bnchmrk.pct_change(1)[1:]

# %%
asset_ret.plot(figsize=(16,8))
bnchmrk_ret.plot()
plt.legend()

# %%
plt.figure(figsize=(16,8))
plt.scatter(bnchmrk_ret,asset_ret,alpha=0.50)
plt.xlabel('SPY RET')
plt.ylabel('AAPL RET')
# Out:
# Text(0, 0.5, 'AAPL RET')

# %%
AAPL = asset_ret.values
SPY = bnchmrk_ret.values

# %%
spy_constant = sm.add_constant(SPY)

# %%
model = regression.linear_model.OLS(AAPL,spy_constant).fit()
model.params
# Out:
# array([1.96350284e-05, 1.02360032e+00])

# %%
alpha,beta = model.params

# %%
alpha,beta
# Out:
# (1.963502838912704e-05, 1.0236003202184094)

# %%
spy_constant
# Out:
# array([[ 1.00000000e+00,  1.69129773e-03],
#        [ 1.00000000e+00, -1.26141810e-02],
#        [ 1.00000000e+00, -2.39914733e-02],
#        [ 1.00000000e+00, -1.09766589e-02],
#        [ 1.00000000e+00,  9.89821218e-04],
#        [ 1.00000000e+00,  8.06833242e-03],
#        [ 1.00000000e+00, -2.49405804e-02],
#        [ 1.00000000e+00,  1.64166898e-02],
#        [ 1.00000000e+00, -2.14659117e-02],
#        [ 1.00000000e+00,  1.33117362e-03],
#        [ 1.00000000e+00, -1.28152304e-02],
#        [ 1.00000000e+00,  5.60201045e-03],
#        [ 1.00000000e+00,  2.05154511e-02],
#        [ 1.00000000e+00, -1.51163970e-02],
#        [ 1.00000000e+00,  1.36430509e-02],
#        [ 1.00000000e+00, -1.08832621e-02],
#        [ 1.00000000e+00,  5.20910384e-03],
#        [ 1.00000000e+00,  2.43771027e-02],
#        [ 1.00000000e+00, -3.61273385e-04],
#        [ 1.00000000e+00, -1.80221739e-02],
#        [ 1.00000000e+00,  5.99478716e-03],
#        [ 1.00000000e+00,  1.56849685e-03],
#        [ 1.00000000e+00, -1.90504078e-02],
#        [ 1.00000000e+00, -1.34606475e-02],
#        [ 1.00000000e+00,  5.37245973e-05],
#        [ 1.00000000e+00, -8.62933584e-04],
#        [ 1.00000000e+00, -1.30078522e-02],
#        [ 1.00000000e+00,  2.06167063e-02],
#        [ 1.00000000e+00,  1.68785472e-02],
#        [ 1.00000000e+00,  1.63345975e-02],
#        [ 1.00000000e+00, -4.09592667e-03],
#        [ 1.00000000e+00, -4.68233907e-04],
#        [ 1.00000000e+00,  1.44790946e-02],
#        [ 1.00000000e+00, -1.26297708e-02],
#        [ 1.00000000e+00,  4.57570374e-03],
#        [ 1.00000000e+00,  1.21116904e-02],
#        [ 1.00000000e+00, -2.30133868e-03],
#        [ 1.00000000e+00, -7.84244340e-03],
#        [ 1.00000000e+00,  2.35071763e-02],
#        [ 1.00000000e+00,  4.49234136e-03],
#        [ 1.00000000e+00,  3.91947647e-03],
#        [ 1.00000000e+00,  3.25383240e-03],
#        [ 1.00000000e+00,  7.97928840e-04],
#        [ 1.00000000e+00, -1.09175964e-02],
#        [ 1.00000000e+00,  4.93937407e-03],
#        [ 1.00000000e+00,  8.02556810e-04],
#        [ 1.00000000e+00,  1.61369197e-02],
#        [ 1.00000000e+00, -1.28223692e-03],
#        [ 1.00000000e+00, -1.62949244e-03],
#        [ 1.00000000e+00,  5.78715576e-03],
#        [ 1.00000000e+00,  6.34415700e-03],
#        [ 1.00000000e+00,  3.92965206e-03],
#        [ 1.00000000e+00,  1.41886517e-03],
#        [ 1.00000000e+00, -5.37589837e-04],
#        [ 1.00000000e+00, -6.59931391e-03],
#        [ 1.00000000e+00, -4.42915716e-04],
#        [ 1.00000000e+00,  5.90566611e-04],
#        [ 1.00000000e+00,  9.25043222e-03],
#        [ 1.00000000e+00,  4.38750280e-03],
#        [ 1.00000000e+00, -2.42686283e-03],
#        [ 1.00000000e+00,  6.81197713e-03],
#        [ 1.00000000e+00, -3.23811574e-03],
#        [ 1.00000000e+00, -9.98779736e-03],
#        [ 1.00000000e+00,  1.09211081e-02],
#        [ 1.00000000e+00, -1.19657858e-02],
#        [ 1.00000000e+00,  2.69677621e-03],
#        [ 1.00000000e+00, -2.34698605e-03],
#        [ 1.00000000e+00,  9.31262893e-03],
#        [ 1.00000000e+00,  1.01007136e-02],
#        [ 1.00000000e+00,  4.84583507e-05],
#        [ 1.00000000e+00, -1.10588448e-03],
#        [ 1.00000000e+00,  7.02691107e-03],
#        [ 1.00000000e+00,  3.15404062e-03],
#        [ 1.00000000e+00,  9.52913509e-04],
#        [ 1.00000000e+00, -5.37863085e-03],
#        [ 1.00000000e+00,  0.00000000e+00],
#        [ 1.00000000e+00, -1.72258726e-03],
#        [ 1.00000000e+00,  1.48599979e-03],
#        [ 1.00000000e+00,  2.05812797e-03],
#        [ 1.00000000e+00, -9.07537367e-03],
#        [ 1.00000000e+00, -5.39915768e-03],
#        [ 1.00000000e+00,  7.94856634e-03],
#        [ 1.00000000e+00, -8.70305733e-03],
#        [ 1.00000000e+00, -5.57838583e-03],
#        [ 1.00000000e+00, -1.95177984e-04],
#        [ 1.00000000e+00,  3.65910725e-03],
#        [ 1.00000000e+00,  8.26356344e-04],
#        [ 1.00000000e+00,  1.24339836e-02],
#        [ 1.00000000e+00, -9.35486578e-03],
#        [ 1.00000000e+00,  2.90572754e-04],
#        [ 1.00000000e+00, -8.71407822e-03],
#        [ 1.00000000e+00,  9.86538788e-03],
#        [ 1.00000000e+00, -9.33382562e-03],
#        [ 1.00000000e+00,  2.93078042e-04],
#        [ 1.00000000e+00, -3.46506913e-03],
#        [ 1.00000000e+00,  6.31743194e-03],
#        [ 1.00000000e+00, -1.36264341e-03],
#        [ 1.00000000e+00,  1.29619944e-02],
#        [ 1.00000000e+00,  6.78321324e-03],
#        [ 1.00000000e+00,  2.86954926e-04],
#        [ 1.00000000e+00,  4.29913724e-03],
#        [ 1.00000000e+00, -1.90274465e-03],
#        [ 1.00000000e+00,  2.04918494e-03],
#        [ 1.00000000e+00,  3.04360425e-03],
#        [ 1.00000000e+00, -2.98705938e-03],
#        [ 1.00000000e+00,  5.08875861e-03],
#        [ 1.00000000e+00,  1.56115647e-03],
#        [ 1.00000000e+00,  3.25973552e-03],
#        [ 1.00000000e+00, -1.36564224e-03],
#        [ 1.00000000e+00, -9.47743661e-03],
#        [ 1.00000000e+00, -7.71165335e-03],
#        [ 1.00000000e+00, -1.96703264e-03],
#        [ 1.00000000e+00, -1.39398469e-03],
#        [ 1.00000000e+00,  2.98446500e-03],
#        [ 1.00000000e+00, -3.72434213e-03],
#        [ 1.00000000e+00,  6.44016028e-03],
#        [ 1.00000000e+00,  2.83854568e-03],
#        [ 1.00000000e+00, -1.63108739e-03],
#        [ 1.00000000e+00,  1.30225594e-02],
#        [ 1.00000000e+00, -3.59093036e-02],
#        [ 1.00000000e+00, -1.79096347e-02],
#        [ 1.00000000e+00,  1.80360507e-02],
#        [ 1.00000000e+00,  1.70274010e-02],
#        [ 1.00000000e+00,  1.36457245e-02],
#        [ 1.00000000e+00,  2.10053747e-03],
#        [ 1.00000000e+00, -7.19333052e-03],
#        [ 1.00000000e+00,  5.99790141e-03],
#        [ 1.00000000e+00, -6.20135092e-04],
#        [ 1.00000000e+00,  1.48903132e-02],
#        [ 1.00000000e+00,  3.52695490e-03],
#        [ 1.00000000e+00,  7.26350631e-03],
#        [ 1.00000000e+00, -1.39634247e-04],
#        [ 1.00000000e+00,  5.58341467e-03],
#        [ 1.00000000e+00, -1.34168748e-03],
#        [ 1.00000000e+00,  2.68729133e-03],
#        [ 1.00000000e+00, -1.01679161e-03],
#        [ 1.00000000e+00,  4.16305890e-03],
#        [ 1.00000000e+00, -3.77713802e-03],
#        [ 1.00000000e+00,  4.48513588e-03],
#        [ 1.00000000e+00, -2.71600677e-03],
#        [ 1.00000000e+00,  4.61666093e-04],
#        [ 1.00000000e+00, -1.06114830e-03],
#        [ 1.00000000e+00,  1.15458661e-03],
#        [ 1.00000000e+00,  1.61451062e-03],
#        [ 1.00000000e+00, -8.28813371e-04],
#        [ 1.00000000e+00, -6.40745681e-03],
#        [ 1.00000000e+00,  2.92291054e-03],
#        [ 1.00000000e+00,  1.06394616e-03],
#        [ 1.00000000e+00,  8.17872684e-03],
#        [ 1.00000000e+00, -5.95764781e-04],
#        [ 1.00000000e+00,  5.96119929e-04],
#        [ 1.00000000e+00, -2.47489882e-03],
#        [ 1.00000000e+00,  4.64057500e-03],
#        [ 1.00000000e+00, -8.68719633e-04],
#        [ 1.00000000e+00,  2.88366765e-03],
#        [ 1.00000000e+00, -5.15769184e-03],
#        [ 1.00000000e+00,  1.88110762e-03],
#        [ 1.00000000e+00,  2.24399946e-03],
#        [ 1.00000000e+00, -1.46233668e-03],
#        [ 1.00000000e+00, -4.54983530e-05],
#        [ 1.00000000e+00,  2.01331687e-03],
#        [ 1.00000000e+00, -5.11487902e-03],
#        [ 1.00000000e+00, -6.88645976e-04],
#        [ 1.00000000e+00, -1.88320009e-03],
#        [ 1.00000000e+00,  4.92423344e-03],
#        [ 1.00000000e+00, -1.64844412e-03],
#        [ 1.00000000e+00, -2.84398720e-03],
#        [ 1.00000000e+00,  4.58183954e-05],
#        [ 1.00000000e+00,  4.50799904e-03],
#        [ 1.00000000e+00,  3.02253460e-03],
#        [ 1.00000000e+00, -9.15599445e-05],
#        [ 1.00000000e+00, -2.28291960e-03],
#        [ 1.00000000e+00, -2.39349561e-02],
#        [ 1.00000000e+00,  1.43476023e-02],
#        [ 1.00000000e+00, -1.43754747e-02],
#        [ 1.00000000e+00, -3.75492820e-04],
#        [ 1.00000000e+00,  9.99310589e-03],
#        [ 1.00000000e+00, -3.86545848e-03],
#        [ 1.00000000e+00,  1.87345970e-04],
#        [ 1.00000000e+00,  4.69060268e-05],
#        [ 1.00000000e+00,  1.12454078e-02],
#        [ 1.00000000e+00,  6.30148022e-03],
#        [ 1.00000000e+00, -5.47922922e-03],
#        [ 1.00000000e+00, -8.10237904e-03],
#        [ 1.00000000e+00,  6.20809292e-03],
#        [ 1.00000000e+00,  4.96346128e-03],
#        [ 1.00000000e+00, -9.04709935e-03],
#        [ 1.00000000e+00,  7.54603887e-03],
#        [ 1.00000000e+00, -2.40412920e-03],
#        [ 1.00000000e+00, -5.09764885e-03],
#        [ 1.00000000e+00,  4.42496269e-03],
#        [ 1.00000000e+00,  6.95726764e-04],
#        [ 1.00000000e+00, -3.42943724e-03],
#        [ 1.00000000e+00,  5.20844748e-03],
#        [ 1.00000000e+00, -1.26296786e-02],
#        [ 1.00000000e+00,  1.31191476e-03],
#        [ 1.00000000e+00, -3.27552884e-03],
#        [ 1.00000000e+00,  5.16543028e-04],
#        [ 1.00000000e+00, -3.47216232e-03],
#        [ 1.00000000e+00,  6.26222599e-03],
#        [ 1.00000000e+00,  2.66715378e-03],
#        [ 1.00000000e+00, -1.86659587e-03],
#        [ 1.00000000e+00,  4.67482575e-04],
#        [ 1.00000000e+00,  4.25286120e-03],
#        [ 1.00000000e+00, -3.35086325e-03],
#        [ 1.00000000e+00, -2.00746148e-03],
#        [ 1.00000000e+00, -2.66670086e-03],
#        [ 1.00000000e+00, -2.95566255e-03],
#        [ 1.00000000e+00,  4.70980375e-05],
#        [ 1.00000000e+00, -7.24536552e-03],
#        [ 1.00000000e+00, -6.01848526e-03],
#        [ 1.00000000e+00, -4.57714950e-03],
#        [ 1.00000000e+00, -1.10172286e-03],
#        [ 1.00000000e+00,  2.20570771e-02],
#        [ 1.00000000e+00,  4.50408106e-03],
#        [ 1.00000000e+00,  1.06018505e-02],
#        [ 1.00000000e+00,  2.49553307e-03],
#        [ 1.00000000e+00, -2.30496384e-03],
#        [ 1.00000000e+00,  7.85308295e-04],
#        [ 1.00000000e+00,  7.80301806e-03],
#        [ 1.00000000e+00, -1.87832620e-03],
#        [ 1.00000000e+00,  5.14071578e-03],
#        [ 1.00000000e+00, -2.23761773e-03],
#        [ 1.00000000e+00,  7.55140062e-03],
#        [ 1.00000000e+00,  1.95338742e-03],
#        [ 1.00000000e+00,  5.43818407e-04],
#        [ 1.00000000e+00,  3.71568804e-03],
#        [ 1.00000000e+00, -4.69495398e-03],
#        [ 1.00000000e+00,  1.95031195e-03],
#        [ 1.00000000e+00, -2.39912157e-03],
#        [ 1.00000000e+00, -3.67543266e-03],
#        [ 1.00000000e+00,  5.00882043e-04],
#        [ 1.00000000e+00,  6.00879258e-03],
#        [ 1.00000000e+00,  3.16732922e-03],
#        [ 1.00000000e+00,  1.30806857e-02],
#        [ 1.00000000e+00,  2.44876992e-03],
#        [ 1.00000000e+00,  6.04072526e-03],
#        [ 1.00000000e+00, -1.14806548e-03],
#        [ 1.00000000e+00,  6.67412980e-03],
#        [ 1.00000000e+00, -8.25422327e-03],
#        [ 1.00000000e+00,  4.11699678e-03],
#        [ 1.00000000e+00, -1.95571002e-03],
#        [ 1.00000000e+00,  2.17747431e-03],
#        [ 1.00000000e+00,  3.85745714e-03],
#        [ 1.00000000e+00, -2.78256186e-03],
#        [ 1.00000000e+00, -1.72744285e-03],
#        [ 1.00000000e+00,  1.46425145e-03],
#        [ 1.00000000e+00,  2.48111269e-03],
#        [ 1.00000000e+00, -8.26466488e-03],
#        [ 1.00000000e+00, -2.22773591e-04],
#        [ 1.00000000e+00, -3.65499707e-03]])

# %%
min_spy = bnchmrk_ret.values.min()
max_spy = bnchmrk_ret.values.max()
spy_line=np.linspace(min_spy,max_spy,100)
y = spy_line*beta + alpha
plt.scatter(bnchmrk_ret,asset_ret,alpha=0.6,s=50)
plt.plot(spy_line,y,c='r')
plt.xlabel('SPY Ret')
plt.xlabel('AAPL Ret')
# Out:
# Text(0.5, 0, 'AAPL Ret')

# %%
hedged = -1*(beta*bnchmrk_ret) + asset_ret

# %%
hedged.plot(label='AAPL with Hedge',figsize=(16,8))
asset_ret.plot(alpha=0.5)
bnchmrk_ret.plot(alpha=0.5)
plt.legend()

# %%
def alpha_beta(benchmark_ret,stock):
    benchmark = sm.add_constant(benchmark_ret)
    
    model = regression.linear_model.OLS(stock,benchmark).fit()
    return model.params[0],model.params[1]

# %%
benchmark2016 = web.DataReader('SPY','yahoo',start,end)
asset2016 = web.DataReader('AAPL','yahoo',start,end)

asset2016 = asset2016['Adj Close']
benchmark2016 = benchmark2016['Adj Close']
asset_ret2016 = asset2016.pct_change(1)[1:]
benchmark_ret2016 = benchmark2016.pct_change(1)[1:]

aret_values = asset_ret2016.values
bret_values = benchmark_ret2016.values

# %%
alpha2016,beta2016 = alpha_beta(bret_values,aret_values)
print("2016 Values")
print('Alpha:' +str(alpha2016))
print('Beta'+str(beta2016))
# Out:
# 2016 Values
# Alpha:1.963650117302101e-05
# Beta1.0235955562095285

# %%
portfolio = (-1*(beta2016*benchmark_ret2016)) + asset_ret2016

# %%
alpha,beta = alpha_beta(benchmark_ret2016,portfolio)

# %%
print('Portfolio: alpha & beta')
print('alpha'+str(alpha))
print('beta' + str(beta))
# Out:
# Portfolio: alpha & beta
# alpha1.9636501173021337e-05
# beta-4.163336342344337e-17

# %%
portfolio.plot(alpha=0.9,label='AAPL with Hedge',figsize=(16,8))
asset_ret2016.plot(alpha=0.5)
benchmark_ret2016.plot(alpha=0.5)
plt.legend()

# %%
portfolio.mean()
# Out:
# 1.96365011730213e-05

# %%
asset_ret2016.mean()
# Out:
# 0.000573547089911881

# %%
portfolio.std()
# Out:
# 0.012110837675680532

# %%
asset_ret2016.std()
# Out:
# 0.01473111450739106
